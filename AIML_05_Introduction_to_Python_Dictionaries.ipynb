# %% [markdown]
# <a href="https://colab.research.google.com/github/rSith/aiml-python-foundations/blob/main/AIML_05_Introduction_to_Python_Dictionaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
